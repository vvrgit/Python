# %% [markdown]
# <a href="https://colab.research.google.com/github/vvrgit/Python/blob/main/Pandas_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas
stud_data = {
  'Roll No.': [101,102,103],
  'Name': ["ABC", "XYZ","KLM"],
  'Marks': [98,56,23]
}

myvar = pandas.DataFrame(stud_data)

print(myvar)
# Out:
#    Roll No. Name  Marks
# 0       101  ABC     98
# 1       102  XYZ     56
# 2       103  KLM     23

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.2

# %%
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a)
print(myvar)
print(myvar[0])
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64
# 1

# %%
import pandas as pd
a = [1, 7, 2]
myvar = pd.Series(a, index = ["x", "y", "z"])
print(myvar)
print(myvar["x"])
# Out:
# x    1
# y    7
# z    2
# dtype: int64
# 1

# %%
import pandas as pd
student={"ABC":101,"KLM":102,"XYZ":103}
data=pd.Series(student)
data
# Out:
# ABC    101
# KLM    102
# XYZ    103
# dtype: int64

# %%
print(data["ABC"])
# Out:
# 101

# %%
import pandas as pd
student={"ABC":101,"KLM":102,"XYZ":103}
data=pd.Series(student, index=["ABC","XYZ"])
data
# Out:
# ABC    101
# XYZ    103
# dtype: int64

# %%
import pandas as pd
students_data={
    "Roll No.":[101,102,103,104,105],
    "Telugu":[35,40,85,54,96],
    "Maths":[90,56,84,35,72]
}
marks=pd.DataFrame(students_data)
marks
# Out:
#    Roll No.  Telugu  Maths
# 0       101      35     90
# 1       102      40     56
# 2       103      85     84
# 3       104      54     35
# 4       105      96     72

# %%
print(marks.iloc[0])
# Out:
# Roll No.    101
# Telugu       35
# Maths        90
# Name: 0, dtype: int64

# %%
print(marks.loc[[0, 1]])
# Out:
#    Roll No.  Telugu  Maths
# 0       101      35     90
# 1       102      40     56

# %%
import pandas as pd
students_data={
    "Roll No.":[101,102,103,104,105],
    "Telugu":[35,40,85,54,96],
    "Maths":[90,56,84,35,72]
}
marks=pd.DataFrame(students_data,index=["Laxman","Rahul","Rakesh","Ravi","Keshav"])
marks
# Out:
#         Roll No.  Telugu  Maths
# Laxman       101      35     90
# Rahul        102      40     56
# Rakesh       103      85     84
# Ravi         104      54     35
# Keshav       105      96     72

# %%
print(marks.loc["Rahul"])
# Out:
# Roll No.    102
# Telugu       40
# Maths        56
# Name: Rahul, dtype: int64

# %%
print(marks.loc[["Rahul","Keshav"]])
# Out:
#         Roll No.  Telugu  Maths
# Rahul        102      40     56
# Keshav       105      96     72

# %%
import pandas as pd
data=pd.read_csv("/content/realfishdataset - Kaggle.csv")
data.head()
# Out:
#     ph  temperature  turbidity   fish
# 0  6.0         27.0        4.0  katla
# 1  7.6         28.0        5.9   sing
# 2  7.8         27.0        5.5   sing
# 3  6.5         31.0        5.5  katla
# 4  8.2         27.0        8.5  prawn

# %%
data.describe()
# Out:
#                ph  temperature   turbidity
# count  591.000000   591.000000  591.000000
# mean     7.532115    21.789306    4.432944
# std      0.810588     4.536612    2.169062
# min      5.500000     4.000000    1.000000
# 25%      6.990000    17.940000    3.480000
# 50%      7.500000    21.060000    3.570000
# 75%      8.200000    24.000000    4.005000
# max      9.000000    35.000000   15.800000

# %%
data["fish"]
# Out:
# 0      katla
# 1       sing
# 2       sing
# 3      katla
# 4      prawn
#        ...
# 586     sing
# 587     sing
# 588     sing
# 589     sing
# 590     sing
# Name: fish, Length: 591, dtype: object

# %%
data["fish"].values
# Out:
# array(['katla', 'sing', 'sing', 'katla', 'prawn', 'katla', 'katla',
#        'katla', 'katla', 'rui', 'rui', 'rui', 'rui', 'rui', 'rui', 'koi',
#        'koi', 'koi', 'koi', 'koi', 'prawn', 'prawn', 'prawn', 'prawn',
#        'prawn', 'sing', 'sing', 'sing', 'sing', 'sing', 'sing', 'pangas',
#        'pangas', 'pangas', 'pangas', 'tilapia', 'tilapia', 'tilapia',
#        'tilapia', 'tilapia', 'pangas', 'pangas', 'pangas', 'tilapia',
#        'prawn', 'silverCup', 'pangas', 'pangas', 'prawn', 'prawn',
#        'prawn', 'prawn', 'prawn', 'koi', 'koi', 'koi', 'koi', 'koi',
#        'pangas', 'pangas', 'pangas', 'pangas', 'katla', 'katla', 'katla',
#        'katla', 'katla', 'katla', 'katla', 'katla', 'prawn', 'prawn',
#        'koi', 'koi', 'koi', 'koi', 'koi', 'tilapia', 'tilapia', 'tilapia',
#        'tilapia', 'tilapia', 'tilapia', 'tilapia', 'tilapia', 'tilapia',
#        'tilapia', 'tilapia', 'tilapia', 'tilapia', 'tilapia', 'tilapia',
# ...

# %%
output_features=data.pop("fish")
output_features.head()
# Out:
# 0    katla
# 1     sing
# 2     sing
# 3    katla
# 4    prawn
# Name: fish, dtype: object

# %%
data.head()
# Out:
#     ph  temperature  turbidity
# 0  6.0         27.0        4.0
# 1  7.6         28.0        5.9
# 2  7.8         27.0        5.5
# 3  6.5         31.0        5.5
# 4  8.2         27.0        8.5

# %%
input_features=data[["ph","temperature","turbidity"]]
input_features.head()
# Out:
#     ph  temperature  turbidity
# 0  6.0         27.0        4.0
# 1  7.6         28.0        5.9
# 2  7.8         27.0        5.5
# 3  6.5         31.0        5.5
# 4  8.2         27.0        8.5

# %%
output_features=data["fish"]
output_features.head()
# Out:
# 0    katla
# 1     sing
# 2     sing
# 3    katla
# 4    prawn
# Name: fish, dtype: object

# %%
data.shape
# Out:
# (591, 4)

# %%
import pandas as pd
students={"Roll No.":[101,102,103,104,105],
         "Telugu":[70,80,50,64,25],
         "English":[90,40,65,85,21]}

data=pd.DataFrame(students)
data.head()
# Out:
#    Roll No.  Telugu  English
# 0       101      70       90
# 1       102      80       40
# 2       103      50       65
# 3       104      64       85
# 4       105      25       21

# %%
Hindi=[25,45,36,95,12]
data["Hindi"]=Hindi
data
# Out:
#    Roll No.  Telugu  English  Hindi
# 0       101      70       90     25
# 1       102      80       40     45
# 2       103      50       65     36
# 3       104      64       85     95
# 4       105      25       21     12

# %%
data.drop(["Hindi","Telugu"], axis=1, inplace=True)
data
# Out:
#    Roll No.  English
# 0       101       90
# 1       102       40
# 2       103       65
# 3       104       85
# 4       105       21

# %%
import pandas as pd
students={"Roll No.":[101,102,103,104,105],
         "Telugu":[70,80,50,64,25],
         "English":[90,40,65,85,21]}

data=pd.DataFrame(students)
data.head()
# Out:
#    Roll No.  Telugu  English
# 0       101      70       90
# 1       102      80       40
# 2       103      50       65
# 3       104      64       85
# 4       105      25       21

# %%
new_row = pd.DataFrame({"Roll No.":106,"Telugu":45,"English":56}, index =[0])
data=pd.concat([new_row,data]).reset_index(drop = True)
data
# Out:
#    Roll No.  Telugu  English
# 0       106      45       56
# 1       101      70       90
# 2       102      80       40
# 3       103      50       65
# 4       104      64       85
# 5       105      25       21

# %%
data.drop(data[data.Telugu < 50].index, inplace=True)
data
# Out:
#    Roll No.  Telugu  English
# 1       101      70       90
# 2       102      80       40
# 3       103      50       65
# 4       104      64       85

# %%
import pandas as pd
data=pd.Series()
print(data)
# Out:
# Series([], dtype: object)

# %%
import pandas as pd
import numpy as np
roll_no=np.array([101,102,103,104,105])
data=pd.Series(roll_no)
print(data)
# Out:
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# dtype: int64

# %%
import pandas as pd
import numpy as np
marks=np.array([95,43,54,76,89,65])
data=pd.Series(marks,index=["Telugu","English","Hindi","Maths","Science","Social"])
print(data)
# Out:
# Telugu     95
# English    43
# Hindi      54
# Maths      76
# Science    89
# Social     65
# dtype: int64

# %%
import pandas as pd
data=pd.Series([54,65,76,87,98,67],index=["Telugu","English","Hindi","Maths","Science","Social"])
data
# Out:
# Telugu     54
# English    65
# Hindi      76
# Maths      87
# Science    98
# Social     67
# dtype: int64

# %%
import pandas as pd
data[3]
# Out:
# <ipython-input-2-859d17b24b72>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data[3]
# 87

# %%
import pandas as pd
data["Maths"]
# Out:
# 87

# %%
import pandas as pd
marks=[43,54,65,76,87,98]
data=pd.DataFrame(marks)
data
# Out:
#     0
# 0  43
# 1  54
# 2  65
# 3  76
# 4  87
# 5  98

# %%
import pandas as pd
marks=[["Telugu",45],["English",56],["Hindi",76]]
data=pd.DataFrame(marks,columns=["Subjet","Marks"])
data
# Out:
#     Subjet  Marks
# 0   Telugu     45
# 1  English     56
# 2    Hindi     76

# %%
import pandas as pd
marks={101:pd.Series([43,54,65],index=["Tel","Eng","Hin"]),
       102:pd.Series([34,45,56],index=["Tel","Eng","Hin"]),
       103:pd.Series([44,55,66],index=["Tel","Eng","Hin"])}

data=pd.DataFrame(marks)
data
# Out:
#      101  102  103
# Tel   43   34   44
# Eng   54   45   55
# Hin   65   56   66

# %%
d=data.shape
sub=input("enter subject")
roll=int(input("enter roll no."))
print("Roll No",roll,"Subject",sub,"Marks",data.loc[sub].loc[roll])
# Out:
# enter subjectTel
# enter roll no.101
# Roll No 101 Subject Tel Marks 43

# %%
sub=input("enter subject")
roll=int(input("enter roll no."))
marks=int(input("enter marks"))
data.at[sub,roll]=marks
data
# Out:
# enter subjectTel
# enter roll no.101
# enter marks53
#      101  102  103
# Tel   53   34   44
# Eng   54   45   55
# Hin   65   56   66

# %%
roll=int(input("Enter roll no."))
failed_sub=data[data[roll]<35].index
print("Telugu:",data.loc["Tel"].loc[roll])
print("English:",data.loc["Eng"].loc[roll])
print("Hindi:",data.loc["Hin"].loc[roll])
print("Total Marks:",data[roll].sum())
print("Total Marks:",data[roll].max())
print("Total Marks:",data[roll].min())
print("Total Marks:",data[roll].mean())
print("Failed Subjects:",failed_sub.values)
# Out:
# Enter roll no.102
# Telugu: 34
# English: 45
# Hindi: 56
# Total Marks: 135
# Total Marks: 56
# Total Marks: 34
# Total Marks: 45.0
# Failed Subjects: ['Tel']

# %%
failed_subjects=data[data[102]<35].index
failed_subjects[0]
# Out:
# 'Tel'

# %%
import pandas as pd
stud_data={
    'Roll No.': [101,102,103,104,105],
    'Tel':[35,45,56,78,89],
    'Eng':[53,54,65,87,98]
}
Marks=pd.DataFrame(stud_data)
Marks
# Out:
#    Roll No.  Tel  Eng
# 0       101   35   53
# 1       102   45   54
# 2       103   56   65
# 3       104   78   87
# 4       105   89   98

# %%
import pandas as pd

students_data={
    "Roll No.":[101,102,103,104,105],
    "Telugu":[35,98,43,65,78],
    "English":[87,45,98,65,34],
    "Hindi":[45,26,78,45,67],
    "Maths":[45,56,67,78,89],
    "Science":[23,34,45,56,76],
    "Social":[32,43,54,65,67]}
data=pd.DataFrame(students_data)

Hall_Ticket_No=int(input("enter hall ticket no."))
ind=data[data["Roll No."]==Hall_Ticket_No].index

score_card=data.loc[[ind[0]]]
score_card.pop("Roll No.")
per=score_card.loc[ind[0]].sum()*100/600

fail=score_card[score_card < 35].count()
no_of_sub_fail=fail.sum()
failed_sub=fail[fail==1].index



if(no_of_sub_fail>0):
  print("Status: Fail")
  print("Failed Subjects:",failed_sub)
else:
  print("Status: Pass")
  print("Pass Percentage:",per)


score_card
# Out:
# enter hall ticket no.102
# Status: Fail
# Failed Subjects: Index(['Hindi', 'Science'], dtype='object')
#    Telugu  English  Hindi  Maths  Science  Social
# 1      98       45     26     56       34      43

# %%
data
# Out:
#    Roll No.  Telugu  English  Hindi  Maths  Science  Social
# 0       101      35       87     45     45       23      32
# 1       102      98       45     26     56       34      43
# 2       103      43       98     78     67       45      54
# 3       104      65       65     45     78       56      65
# 4       105      78       34     67     89       76      67

# %%
import pandas as pd
covid={
    "Fever":[96,98,96.8,99,102],
    "O2":[86,100,95,98,92],
    "Cold":[0,0,1,0,1],
    "Cough":[1,0,1,0,1]
}
covid_data=pd.DataFrame(covid)
covid_data
# Out:
#    Fever   O2  Cold  Cough
# 0   96.0   86     0      1
# 1   98.0  100     0      0
# 2   96.8   95     1      1
# 3   99.0   98     0      0
# 4  102.0   92     1      1

# %%
import matplotlib.pyplot as plt
plt.plot(covid_data["Fever"],marker = 'x',ls = '-')

# %%
from sklearn.preprocessing import MinMaxScaler
scalar=MinMaxScaler()
scalar.fit(covid_data)
covid_data_norm=scalar.transform(covid_data)
covid_data_norm
# Out:
# array([[0.        , 0.        , 0.        , 1.        ],
#        [0.33333333, 1.        , 0.        , 0.        ],
#        [0.13333333, 0.64285714, 1.        , 1.        ],
#        [0.5       , 0.85714286, 0.        , 0.        ],
#        [1.        , 0.42857143, 1.        , 1.        ]])

# %%
# Out:
# array([[0.        , 0.        , 0.        , 1.        ],
#        [0.33333333, 1.        , 0.        , 0.        ],
#        [0.13333333, 0.64285714, 1.        , 1.        ],
#        [0.5       , 0.85714286, 0.        , 0.        ],
#        [1.        , 0.42857143, 1.        , 1.        ]])
